# %%
import random
suma1=0
def dados():
    x=random.randint(1, 6)
    return (x)
n=int(input("ingresa las veces del experimento "))
i=0
while i<n:
    dados()
    print(dados())
    i=i+1
    if dados()==1:
        suma1=+1
print(suma1)
